# %%
print("没有换行符")
print("有\n换行符")
print("多个\n换行符\n在这里")
print("\n开头换行")
print("结尾换行\n")
print("同时用\t制表符和\n换行符")
print("使用\\n显示换行符")
# Out:
# 没有换行符
# 有
# 换行符
# 多个
# 换行符
# 在这里
#
# 开头换行
# 结尾换行
#
# 同时用	制表符和
# 换行符
# 使用\n显示换行符
