# %%
# 健康食谱
diet = ['西红柿', '花椰菜', '黄瓜', '牛柳', '虾仁']
for x in range(0,5):
    for y in range(0,5):
        if not(x == y):
            print("{}炒{}".format(diet[x], diet[y]))
# Out:
# 西红柿炒花椰菜
# 西红柿炒黄瓜
# 西红柿炒牛柳
# 西红柿炒虾仁
# 花椰菜炒西红柿
# 花椰菜炒黄瓜
# 花椰菜炒牛柳
# 花椰菜炒虾仁
# 黄瓜炒西红柿
# 黄瓜炒花椰菜
# 黄瓜炒牛柳
# 黄瓜炒虾仁
# 牛柳炒西红柿
# 牛柳炒花椰菜
# 牛柳炒黄瓜
# 牛柳炒虾仁
# 虾仁炒西红柿
# 虾仁炒花椰菜
# 虾仁炒黄瓜
# 虾仁炒牛柳
